# %% [markdown]
# # EA4 — Proyecto integrador y respuesta a la pregunta orientadora
#
# **Big Data (ISD-25)** · Ingeniería de Software y Datos · IU Digital de Antioquia
#
# | | |
# |---|---|
# | **Grupo** | *(número)* |
# | **Integrantes** | *(nombre 1) · (nombre 2) · (nombre 3)* |
# | **Caso de estudio** | *(Wanderbricks u otro)* |
# | **Fecha de entrega** | domingo 27 de septiembre |
# | **🎥 Enlace al video** | *(pegar aquí — 12 a 15 minutos, mínimo 5 minutos por integrante)* |
#
# > ⚠️ **Antes de entregar:** verificar que el enlace del video abra desde una cuenta distinta a la propia.
# > Un enlace inaccesible se califica como no entregado.

# %% [markdown]
# ---
# ## 1. Contexto y problema
# ### La pregunta orientadora
#
# > Una empresa que vende productos por internet quiere tomar una decisión sobre su
# > estrategia comercial. Sus canales de venta son un portal propio, una página de Facebook,
# > una cuenta de Instagram, una de TikTok y atención por WhatsApp Business. Los datos
# > recogidos sobre los usuarios van desde los pedidos realizados hasta sus posibles
# > preferencias —enlaces que visitan, productos que comentan, ubicación geográfica desde
# > donde se conectan— así como las interacciones que se producen entre ellos.
# > **¿Bajo qué paradigma, con qué herramientas y con qué arquitectura puede analizarse
# > toda esta información?**

# %% [markdown]
# ---
# ## 2. Descripción de los datos
#
# *Consolidación de lo trabajado en las EA1, EA2 y EA3.*

# %% [markdown]
# ---
# ## 3. Decisiones de diseño y justificación
# ### 3.1 Arquitectura de referencia construida
#
# *Integrar EA1, EA2 y EA3 en una sola arquitectura documentada. No es un resumen
# de los tres trabajos: es mostrarlos funcionando como un sistema.*
#
# ### 3.2 Arquitectura alternativa propuesta
#
# *Al menos una de estas rutas: pila open source autogestionada (Spark + Delta o Iceberg +
# almacenamiento de objetos + orquestador), otro proveedor gestionado (BigQuery, Snowflake,
# Microsoft Fabric, EMR), o una arquitectura orientada a streaming.
# Cada componente con sus especificaciones y su función.*
#
# ### 3.3 Matriz de decisión ponderada
#
# *Los pesos deben sustentarse: por qué ese criterio pesa más que aquel en este caso.*
#
# | Criterio | Peso | Arquitectura construida | Arquitectura alternativa |
# |---|---|---|---|
# | | | | |
# | | | | |
# | **Total ponderado** | | | |
#
# **Ventajas y desventajas de cada una:**

# %% [markdown]
# ---
# ## 4. Implementación
# ### 4.1 Prototipo de un componente de la alternativa
#
# *Aunque sea a escala reducida. La propuesta no puede ser solo un documento.*

# %%
# TODO: prototipo funcional

# %% [markdown]
# ---
# ## 5. Resultados
# ### Respuesta a la pregunta orientadora
#
# **Paradigma:**
#
# **Herramientas:**
#
# **Arquitectura:**
#
# *La respuesta debe ser explícita y concreta, y derivarse del trabajo hecho,
# no de una recomendación general de la industria.*

# %% [markdown]
# ---
# ## 6. Conclusiones
#
# *Qué funcionó, qué no funcionó y qué harían distinto si empezaran de nuevo.
# Las conclusiones deben derivarse de los resultados mostrados arriba, no de expectativas generales.*

# %% [markdown]
# ---
# ## 7. Reparto del trabajo y uso de IA
#
# | Integrante | De qué se encargó | Qué sustenta en el video |
# |---|---|---|
# | | | |
# | | | |
# | | | |
#
# **Uso de asistentes de IA:** *(indicar en qué partes se usó el Databricks Assistant u otra
# herramienta. Está permitido; lo que se evalúa es que cada integrante pueda explicar
# cualquier línea del código en el video.)*
#
# > Este reparto debe coincidir con lo que cada persona demuestra en el video y con el
# > historial de commits del repositorio. Las tres fuentes se contrastan al calificar.

# %% [markdown]
# ---
# ## 📹 Preguntas obligatorias de sustentación
#
# Cada integrante responde estas tres preguntas en su intervención del video:
#
# 1. ¿En qué es mejor y en qué es peor su arquitectura alternativa frente a la que construyeron?
# 2. Justifique los pesos que asignó en la matriz de decisión.
# 3. Responda la pregunta orientadora en menos de un minuto.

# %% [markdown]
# ---
# ## ✅ Antes de entregar
#
# - [ ] La arquitectura de referencia integra las tres evidencias anteriores
# - [ ] El prototipo del componente alternativo funciona
# - [ ] La matriz de decisión tiene pesos sustentados, no arbitrarios
# - [ ] La pregunta orientadora está respondida de forma explícita
# - [ ] La conclusión individual está publicada en el foro del curso
# - [ ] Todo confirmado en /ea4 y el HTML subido a Canvas
